# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#loading the given dataset
train = pd.read_csv("C:\\Users\\Viji\\Desktop\\Bank loan\\credit_train.csv")
test = pd.read_csv("C:\\Users\\Viji\\Desktop\\Bank loan\\credit_test.csv")

# %%
# Checking the Columns in train  data
train.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Loan Status', 'Current Loan Amount', 'Term',
#        'Credit Score', 'Annual Income', 'Years in current job',
#        'Home Ownership', 'Purpose', 'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
#checking the columns in test data
test.columns
# Out:
# Index(['Loan ID', 'Customer ID', 'Current Loan Amount', 'Term', 'Credit Score',
#        'Annual Income', 'Years in current job', 'Home Ownership', 'Purpose',
#        'Monthly Debt', 'Years of Credit History',
#        'Months since last delinquent', 'Number of Open Accounts',
#        'Number of Credit Problems', 'Current Credit Balance',
#        'Maximum Open Credit', 'Bankruptcies', 'Tax Liens'],
#       dtype='object')

# %%
#checking the difference in test and train data
train.columns.difference(test.columns)
# Out:
# Index(['Loan Status'], dtype='object')

# %%
#checking the shape of the data
print("train size :",train.shape)
print("test size :",test.shape)
# Out:
# train size : (100514, 19)
# test size : (10353, 18)

# %%
#adding an extra column in test and train then will concat it for data preprocessing
train["source"] = "train"
test["source"] = "test"

# %%
test.head()
# Out:
#                                 Loan ID                           Customer ID  \
# 0  f738779f-c726-40dc-92cf-689d73af533d  ded0b3c3-6bf4-4091-8726-47039f2c1b90
# 1  6dcc0947-164d-476c-a1de-3ae7283dde0a  1630e6e3-34e3-461a-8fda-09297d3140c8
# 2  f7744d01-894b-49c3-8777-fc6431a2cff1  2c60938b-ad2b-4702-804d-eeca43949c52
# 3  83721ffb-b99a-4a0f-aea5-ef472a138b41  12116614-2f3c-4d16-ad34-d92883718806
# 4  08f3789f-5714-4b10-929d-e1527ab5e5a3  39888105-fd5f-4023-860a-30a3e6f5ccb7
#
#    Current Loan Amount        Term  Credit Score  Annual Income  \
# 0             611314.0  Short Term         747.0      2074116.0
# 1             266662.0  Short Term         734.0      1919190.0
# 2             153494.0  Short Term         709.0       871112.0
# 3             176242.0  Short Term         727.0       780083.0
# 4             321992.0  Short Term         744.0      1761148.0
#
#   Years in current job Home Ownership             Purpose  Monthly Debt  \
# ...

# %%
train.head()
# Out:
#                                 Loan ID                           Customer ID  \
# 0  14dd8831-6af5-400b-83ec-68e61888a048  981165ec-3274-42f5-a3b4-d104041a9ca9
# 1  4771cc26-131a-45db-b5aa-537ea4ba5342  2de017a3-2e01-49cb-a581-08169e83be29
# 2  4eed4e6a-aa2f-4c91-8651-ce984ee8fb26  5efb2b2b-bf11-4dfd-a572-3761a2694725
# 3  77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a  e777faab-98ae-45af-9a86-7ce5b33b1011
# 4  d4062e70-befa-4995-8643-a0de73938182  81536ad9-5ccf-4eb8-befb-47a4d608658e
#
#   Loan Status  Current Loan Amount        Term  Credit Score  Annual Income  \
# 0  Fully Paid             445412.0  Short Term         709.0      1167493.0
# 1  Fully Paid             262328.0  Short Term           NaN            NaN
# 2  Fully Paid           99999999.0  Short Term         741.0      2231892.0
# 3  Fully Paid             347666.0   Long Term         721.0       806949.0
# 4  Fully Paid             176220.0  Short Term           NaN            NaN
#
# ...

# %%
dataf = pd.concat([train,test],axis=0,sort=False)

# %%
dataf.head()
# Out:
#                                 Loan ID                           Customer ID  \
# 0  14dd8831-6af5-400b-83ec-68e61888a048  981165ec-3274-42f5-a3b4-d104041a9ca9
# 1  4771cc26-131a-45db-b5aa-537ea4ba5342  2de017a3-2e01-49cb-a581-08169e83be29
# 2  4eed4e6a-aa2f-4c91-8651-ce984ee8fb26  5efb2b2b-bf11-4dfd-a572-3761a2694725
# 3  77598f7b-32e7-4e3b-a6e5-06ba0d98fe8a  e777faab-98ae-45af-9a86-7ce5b33b1011
# 4  d4062e70-befa-4995-8643-a0de73938182  81536ad9-5ccf-4eb8-befb-47a4d608658e
#
#   Loan Status  Current Loan Amount        Term  Credit Score  Annual Income  \
# 0  Fully Paid             445412.0  Short Term         709.0      1167493.0
# 1  Fully Paid             262328.0  Short Term           NaN            NaN
# 2  Fully Paid           99999999.0  Short Term         741.0      2231892.0
# 3  Fully Paid             347666.0   Long Term         721.0       806949.0
# 4  Fully Paid             176220.0  Short Term           NaN            NaN
#
# ...

# %%
#checking for null values in the data set provided
dataf.isna().sum()
# Out:
# Loan ID                           867
# Customer ID                       867
# Loan Status                     10867
# Current Loan Amount               867
# Term                              867
# Credit Score                    22002
# Annual Income                   22002
# Years in current job             5516
# Home Ownership                    867
# Purpose                           867
# Monthly Debt                      867
# Years of Credit History           867
# Months since last delinquent    59314
# Number of Open Accounts           867
# Number of Credit Problems         867
# Current Credit Balance            867
# Maximum Open Credit               869
# Bankruptcies                     1093
# Tax Liens                         878
# source                              0
# dtype: int64

# %%
#Checking for the information about the new data frame
dataf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110867 entries, 0 to 10352
# Data columns (total 20 columns):
# Loan ID                         110000 non-null object
# Customer ID                     110000 non-null object
# Loan Status                     100000 non-null object
# Current Loan Amount             110000 non-null float64
# Term                            110000 non-null object
# Credit Score                    88865 non-null float64
# Annual Income                   88865 non-null float64
# Years in current job            105351 non-null object
# Home Ownership                  110000 non-null object
# Purpose                         110000 non-null object
# Monthly Debt                    110000 non-null float64
# Years of Credit History         110000 non-null float64
# Months since last delinquent    51553 non-null float64
# Number of Open Accounts         110000 non-null float64
# Number of Credit Problems       110000 non-null float64
# ...

# %%
#Checking for the basic statistical information about the data
dataf.describe()
# Out:
#        Current Loan Amount  Credit Score  Annual Income   Monthly Debt  \
# count         1.100000e+05  88865.000000   8.886500e+04  110000.000000
# mean          1.174621e+07   1076.594644   1.377449e+06   18468.526823
# std           3.176716e+07   1475.581902   1.063920e+06   12195.564391
# min           1.080200e+04    585.000000   7.662700e+04       0.000000
# 25%           1.795860e+05    705.000000   8.488440e+05   10211.930000
# 50%           3.120260e+05    724.000000   1.173459e+06   16202.440000
# 75%           5.239300e+05    741.000000   1.651670e+06   23997.522500
# max           1.000000e+08   7510.000000   1.655574e+08  435843.280000
#
#        Years of Credit History  Months since last delinquent  \
# count            110000.000000                  51553.000000
# mean                 18.202485                     34.907086
# std                   7.015575                     21.965315
# min                   3.600000                      0.000000
# ...

# %%
#From this I can see that SD of each feature should less than Mean but in few coulmns it greater than Mean which says 
#that particular featur needs to be normalized depending on the Feature

# %%
#Importing In built function the pandas which will give all anamolies in the data which can been fixed as per the report
import pandas_profiling

# %%
pandas_profiling.ProfileReport(dataf)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
#Removing Multicolinearity columns
# Create correlation matrix
corr_matrix = dataf.corr().abs()
# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
# Find index of feature columns with correlation greater than 0.90
to_drop = [column for column in upper.columns if any(upper[column] > 0.90)]

# %%
to_drop
# Out:
# []

# %%
dataf.describe(include = ['object'])
# Out:
#                                      Loan ID  \
# count                                 110000
# unique                                 88354
# top     11922abd-95f3-4079-9cb7-c3cb4f2dd41f
# freq                                       2
#
#                                  Customer ID Loan Status        Term  \
# count                                 110000      100000      110000
# unique                                 88354           2           2
# top     6593ee8f-e1ac-4e3f-9487-1debaaace5c3  Fully Paid  Short Term
# freq                                       2       77361       79503
#
#        Years in current job Home Ownership             Purpose  source
# count                105351         110000              110000  110867
# unique                   11              4                  16       2
# top               10+ years  Home Mortgage  Debt Consolidation   train
# freq                  34206          53277               86430  100514

# %%
#Null values replaced
dataf['Annual Income'] = dataf["Annual Income"].fillna(dataf["Annual Income"].median())

# %%
#Feature Extraction with PCA or Feature selection with correlation matrix --- Any best methods to be considered

# %%
#Training a RandomForest
